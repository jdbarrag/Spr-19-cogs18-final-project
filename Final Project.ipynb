# %%
# Juan Barragan Chavez, PID A13406888, Cogs 18 Final Project
#UCSD Spring 2019 Professor Shannon Ellis



#Imports the method to access the web browesr. Browser_path is meant to define chrome for the webbrowser method 
# code recieved from https://www.codevoila.com/post/45/open-web-browser-window-or-new-tab-with-python
import webbrowser as wb
browser_path = "C:/Program Files (x86)/Google/Chrome/Application/chrome.exe %s"



#Code for the introduction of the project
# Base code recieved from https://stackoverflow.com/questions/33594958/is-it-possible-to-align-a-print-statement-to-the-center-in-python. Code edited by Juan Barragan on 6/4/19
import os
print("Hello! Welcome to my Cogs 18 Final Project! ".center(100))


#Creates the main function for the "food" section. 
#In this section, we have 4 main methods (home,list, random, and recipe)
class Food(object):

    #Creates the "homepage" for the food section. From here, you will read about the different options for the "food" category 
    def food_home (self):
        print("\n \n  \n  Welcome to Cooking section! In this section, we have three options to help further your career as a chef! \n  \n".center(100))
   
        #Description of what this section of the project will do
        fd1 = """\n 
Our first option in cooking section is a WEBSITE LIST. In this list, we have five different websites that soley focus
on food. With these websites, we have the option to look up cooking recipes, read different chef's blogs, stay up to 
date on the latest cooking news, and even learn different wellness tips! 
                """
        
        fd2 = """\n 
Our second option is a bit more of a hands on approach to teaching. When you choose the INGREDIENT option, you are 
taken to a website, My Fridge Food, where you can look up specific recipes based on the ingredients you have at home. 
This teaching method is meant to immediately immerse you in a cooking atmosphere by tailoring a meal specifically around 
you and your meal preferences. The site is fairly easy to use; you select all the ingredients you either have at home or 
that you wish to cook with, then you are taken to a list of recipes that is tailored to your specific request.
        """
        
        fd3 = """\n 
Our last option RECIPE, is meant to help you pursue any pre-existing cooking endeavors you may have. All you have to
to do is type in a food you wish to cook, then you will be taken to a website that has recipes for that specific item. \n 
                """
        
        print(fd1)
        print(fd2)
        print(fd3)
        print("\n If you wish to return to the start page to choose another hobby, please type HOME. \n")
        
        #The three print statements print out the description of the methods
        #Assigns the variables to the class function. (Example:food class to foodNavigation). With this, we can access the methods of the food class
        food_nav = Food()
        
        # Block of code that creates the dialoug box
        #Base code recieved from https://stackoverflow.com/questions/23294658/asking-the-user-for-input-until-they-give-a-valid-response. Code edited by Juan Barragan on 6/4/19
        food_ans = None
        while food_ans is None:
            input_value = input("Which option would you like to choose? : ")
            try:
                food_ans = str(input_value)
                food_ans.lower()
            except ValueError:
                print("{input} is not on the category, please select a valid category.".format(input=input_value))
                
            #If/else statement that will navigate to the next screen        
            if food_ans == 'website list':
                print(food_nav.food_list())
            elif food_ans == 'ingredient':
                print(food_nav.food_search())
            elif food_ans == 'recipe':
                print(food_nav.own_recipe())
            elif food_ans == 'home':
                go_home = startPage()
                print(go_home.home())
            else:
                print("\n Im sorry, {input} is not a valid option. Please select either  Food List, Random, or Recipe \n".format(input=input_value))
                print(food_nav.food_home())
    
    #The main body of code for the food list method
    def food_list (self):
        
        food_nav1 = Food()
    #Creates the dictionary containing all of the food websites
        food_dictionary = {
            "All Recipes" : 'https://www.allrecipes.com/',
            "Food Network" : 'https://www.foodnetwork.com/',
            "The Kitchn" : 'https://www.thekitchn.com/',
            "Yummly" : 'https://www.yummly.com/recipes',
            "Food52" : 'https://food52.com/'
            }
        
        #Meant to seperate the dialoug box and the printed out dictionary in the console output
        print('\n \n')
        #prints out the dictionary vertically
        for i in food_dictionary:
            print(i, " ")
        
        #Base code recieved from https://stackoverflow.com/questions/23294658/asking-the-user-for-input-until-they-give-a-valid-response. Code edited by Juan Barragan on 6/4/19
        answer = None
        while answer is None:
            input_value = input("\n Please Select a website: \n")
            try:
                answer = str(input_value)
                answer.lower()
            except ValueError:
                print("{input} is not on the list, please select a valid website.".format(input=input_value))
             #Creates the loop that will open up the food website
            if answer == "all recipes":
                print('\n https://www.allrecipes.com/_website \n')
                #Base webbrowser code fromhttps://docs.python.org/3/library/webbrowser.html. Edited on 6/6/19
                wb.open_new('https://www.allrecipes.com')
                assert answer == 'all recipes'
            elif answer == 'food network':
                print('\n https://www.foodnetwork.com/ \n')
                wb.open_new('https://www.foodnetwork.com/')
            elif answer == 'the kitchn':
                print('\n https://www.thekitchn.com/ \n')
                wb.open_new('https://www.thekitchn.com/')
            elif answer == 'yummly':
                print('\n https://www.yummly.com/recipes\n')
                wb.open_new('https://www.yummly.com/recipes')
            elif answer == 'food52':
                print('\n https://food52.com/ \n')
                wb.open_new('https://food52.com/')
            else:
                print("\n Sorry, that isn't on the list. Please try again. \n")
                print(food_nav1.food_list())
                
    
    
    def food_search (self):
        print("\n \n \n Ingredients! Where we combine the things around your kitchen to make culinary masterpieces! \n \n \n")
        
        # Block of code that creates the dialoug box
        #Base code recieved from https://stackoverflow.com/questions/23294658/asking-the-user-for-input-until-they-give-a-valid-response. Code edited by Juan Barragan on 6/7/19
        component = None
        while component is None:
            input_ing = input("Please type the word 'go' to begin! : ")
            try:
                choice = str(input_ing)
                choice.lower()
            except ValueError:
                print("{input} is not a valid response. Please type 'go' to begin.".format(input=input_ing))        
            
            if input_ing == "go":
                print('\n \n http://myfridgefood.com/?detailed=true')
                wb.open('http://myfridgefood.com/?detailed=true', new=2)
                assert input_ing == 'go'
                break
            else:
                print("{input} is not a valid response. Please type 'go' to begin.".format(input=input_ing))
    
    
#Creates the function that will search up a users recipe
    def own_recipe(self):
        
        print("\n \n \n Welcome to OWN RECIPE!. To begin, please pick a meal you would like to cook! \n \n \n")
        
        choice = None
        while choice is None:
            input_meal = input("\n Which meal would you like to make? : ")
            try:
                choice = str(input_meal)
                choice.lower()
            except ValueError:
                print("\n {input} is not on the category, please select a valid category.".format(input=input_meal))        
            print("https://www.allrecipes.com/search/results/?wt={input}&sort=re".format(input=input_meal))
            wb.open_new("https://www.allrecipes.com/search/results/?wt={input}&sort=re".format(input=input_meal))
            
            
            
class Games(object):
    
    def games_home(self): 
        
    #Creates the "homepage" for the games section. From here, you will learn how to begin your gaming experience 
        print("\n \n  \n  Welcome to the Video Game section! In this section, you can learn the basics for most video games! \n  \n".center(100))
   
        #Description of what the video game section of the project will do
        gme1 = """\n 
Our first option in games section is a GAMES LIST. To start off the video game section, I give you a list of online flash
game websites you can visit and play. This is the first option because there isn't a better way to learn how to play games 
than to actually play games! These games are all hosted within a browser, meaning you don't have to pay a cent to play them! 
With these sites, you can gain experience playing a variety of different gaming styles including action, racing and adventure 
games!
                """
        
        gme2 = """\n 
Our second option is a bit similar to the game list, where you have the ability to play an online web game, but the difference 
here is that the game is randomly choosen. When you choose RANDOM, you are taken to a random game from cool math games. This is
the second option beacause choosing a game from a wide variety of games may seem daunting to some who are looking to get into 
the hobby. This way, we can get the ball rolling and immediately start you off with the gaming experience. Best part is, the
flash games are from cool math games, which means they are educational!
        """
        
        print(gme1)
        print(gme2)
        print("\n If you wish to return to the start page to choose another hobby, please type HOME. \n")
        
        #The three print statements print out the description of the methods
        #Assigns the variables to the class function. (Example:food class to foodNavigation). With this, we can access the methods of the food class
        games_nav = Games()
        
        # Block of code that creates the dialoug box (same base code for every part)
        #Base code recieved from https://stackoverflow.com/questions/23294658/asking-the-user-for-input-until-they-give-a-valid-response. Code edited by Juan Barragan on 6/4/19
        game_ans = None
        while game_ans is None:
            user_input = input("Which option would you like to choose? : ")
            try:
                game_ans = str(user_input)
                game_ans.lower()
            except ValueError:
                print("{input} is not on the category, please select a valid category.".format(input=user_input))
                
             #If/else statement that will navigate to the next screen        
            if game_ans == 'games list':
                print(games_nav.game_list())
            elif game_ans == 'random':    #FINISH
                print(games_nav.random_game())
            elif game_ans == 'home':
                return_home = startPage()
                print(return_home.home())
            else:
                print("\n Im sorry, {input} is not a valid option. Please select either Games List or Random \n".format(input=user_input))
                print(games_nav.games_home())

     #The main body of code for the game list method
    def game_list (self):
        
        game_nav1 = Games()
    #Creates the dictionary containing all of the flash game websites
        game_dict = {
            "Cool Math Games" : 'https://www.coolmathgames.com/',
            "Miniclip" : 'https://www.miniclip.com/games/en/',
            "kongregate" : 'https://www.kongregate.com/',
            "Agame" : 'http://www.agame.com/',
            "Y8" : 'https://www.y8.com/'
            }
        
        #Meant to seperate the dialoug box and the printed out dictionary in the console output
        print('\n \n')
        #prints out the dictionary vertically
        for i in game_dict:
            print(i, " ")
            
        
        #Base code recieved from https://stackoverflow.com/questions/23294658/asking-the-user-for-input-until-they-give-a-valid-response. Code edited by Juan Barragan on 6/4/19
        my_answer = None
        while my_answer is None:
            your_input = input("\n Please Select a website: \n")
            try:
                your_answer = str(your_input)
                your_answer.lower()
            except ValueError:
                print("{input} is not on the list, please select a valid website.".format(input=your_input))
             #Creates the loop that will open up the food website
            if your_answer == "cool math games":
                print('\n https://www.coolmathgames.com/ \n')
                #Base webbrowser code fromhttps://docs.python.org/3/library/webbrowser.html. Edited on 6/6/19
                wb.open_new('https://www.coolmathgames.com/')
                assert my_answer == 'cool math games'
            elif your_answer == 'miniclip':
                print('\n https://www.miniclip.com/games/en/ \n')
                wb.open_new('https://www.miniclip.com/games/en/')
            elif your_answer == 'kongregate':
                print('\n https://www.kongregate.com/ \n')
                wb.open_new('https://www.kongregate.com/')
            elif your_answer == 'agames':
                print('\n http://www.agame.com/ \n')
                wb.open_new('http://www.agame.com/')
            elif your_answer == 'y8':
                print('\n https://www.y8.com/ \n')
                wb.open_new('https://www.y8.com/')
                assert my_answer == 'y8'
            else:
                print("\n Sorry, that isn't on the list. Please try again. \n")
                print(game_nav1.game_list())
                
    #Code for the random section. Just opens up browser to random flash game            
    def random_game (self):
        
        print("\n \n Welcome to random games! To get start playing, please type LETS PLAY")
        
        
        this_answer = None
        while this_answer is None:
            this_input = input("\n Please Select a website: \n")
            try:
                your_choice = str(this_input)
                your_choice.lower()
            except ValueError:
                print("{input} is not on the list, please select a valid website.".format(input=your_choice))
             #Creates the loop that will open up the food website
            if your_choice == "lets play":
                print('\n https://www.coolmathgames.com/random \n')
                #Base webbrowser code fromhttps://docs.python.org/3/library/webbrowser.html. Edited on 6/6/19
                wb.open_new('https://www.coolmathgames.com/random')
                assert your_choice == 'lets play'
                break
        
        
          
    # Block of code that runs the actual project.
#Base code recieved from https://stackoverflow.com/questions/23294658/asking-the-user-for-input-until-they-give-a-valid-response. Code edited by Juan Barragan on 6/4/19
class startPage(object):
    
    #function that allows the user to return home from the other categories. Also houses the main code
    def home(self):
        intro = """
\n \n \nIn this project, I have created a series of functions that is meant to help facilitate learning a new hobby! 
Navigating through this project is relatively easy, all you have to do is read the instructions as they come up in each
section, then type in the dialoug box which option you would to choose, then you are taken to that section. Each section 
has specific instructions on how to proceed to next part.  \n
                """
        
        
        str1 = """
\nThe two hobbies I have included are COOKING and VIDEO GAMES. For each hobby, I have included some websites to help 
introduce you to the subject matter as well as giving you the ability to seek out specific knowledge for each hobby. To begin,
please select one of the hobbies.
        """
        print (intro)
        print (str1)

        
        ans = None
        while ans is None:
            input_value = input("Please Select a Category: ")
            try:
                ans = str(input_value)
                ans.lower()
            except ValueError:
                print("{input} is not on the category, please select a valid category.".format(input=input_value))
            if ans == 'cooking':
                foodOpt = Food()
                print(foodOpt.food_home())
            elif ans == 'video games':
                gamesOpt = Games()
                print(gamesOpt.games_home())
            else:
                print(" \n Im sorry, {input} is not a valid option. Please select either Cooking or Video Games! \n".format(input=input_value))
      
        
                
#runs the input box at the bottom, underneth the writing                
def __call__(self,home):
    print(home)

#Runs the home section to start the project
code_start = startPage()           
print(code_start.home())
# Out:
#                             Hello! Welcome to my Cogs 18 Final Project!
#
#
#
#
# In this project, I have created a series of functions that is meant to help facilitate learning a new hobby!
# Navigating through this project is relatively easy, all you have to do is read the instructions as they come up in each
# section, then type in the dialoug box which option you would to choose, then you are taken to that section. Each section
# has specific instructions on how to proceed to next part.
#
#
#
#
# The two hobbies I have included are COOKING and VIDEO GAMES. For each hobby, I have included some websites to help
# introduce you to the subject matter as well as giving you the ability to seek out specific knowledge for each hobby. To begin,
# please select one of the hobbies.
